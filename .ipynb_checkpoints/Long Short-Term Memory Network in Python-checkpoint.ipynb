# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt


# Load the dataset
series = pd.read_csv(r'C:\Users\megavba\Downloads\shampoo-sales.csv', 
                     header=0, 
                     index_col=0)


# Summarize the first few rows
print(series.head())

# Line plot
series.plot()
plt.show()
# Out:
#           Sales
# Month
# 1/1/2024  266.0
# 1/2/2024  145.9
# 1/3/2024  183.1
# 1/4/2024  119.3
# 1/5/2024  180.3

# %%
# split data into train and test
X = series.values
train, test = X[0:-12], X[-12:]

# %%
X
# Out:
# array([[266. ],
#        [145.9],
#        [183.1],
#        [119.3],
#        [180.3],
#        [168.5],
#        [231.8],
#        [224.5],
#        [192.8],
#        [122.9],
#        [336.5],
#        [185.9],
#        [194.3],
#        [149.5],
#        [210.1],
#        [273.3],
#        [191.4],
#        [287. ],
#        [226. ],
#        [303.6],
#        [289.9],
#        [421.6],
#        [264.5],
#        [342.3],
#        [339.7],
#        [440.4],
#        [315.9],
#        [439.3],
#        [401.3],
#        [437.4],
#        [575.5],
#        [407.6],
#        [682. ],
#        [475.3],
#        [581.3],
#        [646.9]])

# %%
train
# Out:
# array([[266. ],
#        [145.9],
#        [183.1],
#        [119.3],
#        [180.3],
#        [168.5],
#        [231.8],
#        [224.5],
#        [192.8],
#        [122.9],
#        [336.5],
#        [185.9],
#        [194.3],
#        [149.5],
#        [210.1],
#        [273.3],
#        [191.4],
#        [287. ],
#        [226. ],
#        [303.6],
#        [289.9],
#        [421.6],
#        [264.5],
#        [342.3]])

# %%
test
# Out:
# array([[339.7],
#        [440.4],
#        [315.9],
#        [439.3],
#        [401.3],
#        [437.4],
#        [575.5],
#        [407.6],
#        [682. ],
#        [475.3],
#        [581.3],
#        [646.9]])

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    predictions.append(history[-1])
    # observation
    history.append(test[i])

# %%
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(test)
pyplot.plot(predictions)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # report performance
# ----> 2 rmse = sqrt(mean_squared_error(test, predictions))
#       3 print('RMSE: %.3f' % rmse)
#       4 # line plot of observed vs predicted
#
# NameError: name 'sqrt' is not defined
